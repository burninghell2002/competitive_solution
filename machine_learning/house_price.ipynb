# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("/content/drive/MyDrive/datasets/house_price_kaggle/train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# Check for na values
# and drop columns

# %%
df=df.drop(['MiscFeature','FireplaceQu','PoolQC','Fence','Alley','LotFrontage','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical',],axis=1)
df=df.drop('GarageType',axis=1)

# %%
pd.set_option('display.max_rows',None)
df.isna().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtFinSF1        0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# ...

# %%
df.shape
# Out:
# (1460, 68)

# %% [markdown]
# Encoding

# %%
for i in df:
  LabelEncoder().fit_transform(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-9d066063f77e> in <module>()
#       1 for i in df:
# ----> 2   LabelEncoder().fit_transform(i)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     249         y : array-like of shape [n_samples]
#     250         """
# --> 251         y = column_or_1d(y, warn=True)
#     252         self.classes_, y = _encode(y, encode=True)
#     253         return y
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     795         return np.ravel(y)
#     796
# --> 797     raise ValueError("bad input shape {0}".format(shape))
#     798
#     799
#
# ValueError: bad input shape ()
